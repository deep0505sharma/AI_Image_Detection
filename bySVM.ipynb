# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.svm import SVC

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    labels       f_0       f_1       f_2       f_3       f_4       f_5  \
# 0       0 -2.033875  0.978446 -0.142131 -0.177117 -1.470684  1.669562
# 1       1 -0.348835  0.294815 -0.557577 -2.020773 -1.234715  1.633930
# 2       1  0.113248 -0.607726 -0.947791  0.830851  0.998291  0.498321
# 3       0  1.223321 -0.479048 -1.925789  1.680377  0.021840 -1.453307
# 4       0  0.160109  0.422684 -0.308029  0.227744  0.432854  0.608348
#
#         f_6       f_7       f_8  ...    f_1190    f_1191    f_1192    f_1193  \
# 0 -0.196530 -0.125239 -0.452284  ... -1.111266  0.716084  0.060039  0.301279
# 1 -1.680658 -0.358146  0.166122  ...  0.735240  0.829781  1.521941  1.347946
# 2 -1.493958  0.789572 -1.311018  ...  0.104698  0.616189 -1.035953  2.111387
# 3  0.605559 -0.019024  1.065448  ...  0.360237 -1.957863 -0.123384  1.505329
# 4  0.193832  1.035091 -0.538868  ...  0.416629  1.441766  0.212572 -0.994721
#
#      f_1194    f_1195    f_1196    f_1197    f_1198    f_1199
# ...

# %%
model = SVC(kernel = 'poly', degree = 2)

# %%
X = df.drop('labels',axis = 1)
Y = df['labels']

# %%
X.shape
# Out:
# (5250, 1200)

# %%
df.describe()
# Out:
#             labels          f_0          f_1          f_2          f_3  \
# count  5250.000000  5250.000000  5250.000000  5250.000000  5250.000000
# mean      0.266667     0.385453     0.086769     0.317084     0.400414
# std       0.442259     0.929075     0.898979     0.969380     0.954504
# min       0.000000    -3.462941    -3.605773    -4.078232    -3.344323
# 25%       0.000000    -0.286854    -0.470281    -0.379984    -0.290078
# 50%       0.000000     0.598422     0.071867     0.518698     0.653512
# 75%       1.000000     1.108212     0.609769     1.085552     1.135854
# max       1.000000     3.439295     3.581171     3.991985     3.900672
#
#                f_4          f_5          f_6          f_7          f_8  ...  \
# count  5250.000000  5250.000000  5250.000000  5250.000000  5250.000000  ...
# mean      0.093063     0.173532    -0.174072    -0.074659    -0.135957  ...
# std       0.968625     0.895351     1.001566     0.906168     0.972163  ...
# ...

# %%
df.isnull().sum()
# Out:
# labels    0
# f_0       0
# f_1       0
# f_2       0
# f_3       0
#          ..
# f_1195    0
# f_1196    0
# f_1197    0
# f_1198    0
# f_1199    0
# Length: 1201, dtype: int64

# %%
df.isnull()
# Out:
#       labels    f_0    f_1    f_2    f_3    f_4    f_5    f_6    f_7    f_8  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 5245   False  False  False  False  False  False  False  False  False  False
# 5246   False  False  False  False  False  False  False  False  False  False
# 5247   False  False  False  False  False  False  False  False  False  False
# 5248   False  False  False  False  False  False  False  False  False  False
# 5249   False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
from sklearn.model_selection import train_test_split
train,test,Y_train,Y_tests = train_test_split(X,Y, test_size=0.2, random_state = 20113046)

# %%
model.fit(train,Y_train)
# Out:
# SVC(degree=2, kernel='poly')

# %%
pred = model.predict(train)

# %%
confusion_matrix(pred,Y_train)
# Out:
# array([[3090,    0],
#        [   0, 1110]], dtype=int64)

# %%
import scipy.stats

# %%
print("R2 score : ",model.score(train,Y_train))
# Out:
# R2 score :  1.0

# %%
import seaborn as sns
from matplotlib import pyplot as plt
from scipy.stats import pearsonr
from sklearn.metrics import confusion_matrix

# %%
from sklearn.metrics import classification_report

# %%
print('Classification Report for svm with polynomial kernel :\n',classification_report(Y_train,pred))
# Out:
# Classification Report for svm with polynomial kernel :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3090
#            1       1.00      1.00      1.00      1110
#
#     accuracy                           1.00      4200
#    macro avg       1.00      1.00      1.00      4200
# weighted avg       1.00      1.00      1.00      4200

# %%
pred_test = model.predict(test)

# %%
print("R2 score : ",model.score(test,Y_tests))
# Out:
# R2 score :  0.8495238095238096

# %%
print('Classification Report for svm with polynomial kernel on test data:\n',classification_report(Y_tests,pred_test))
# Out:
# Classification Report for svm with polynomial kernel on test data:
#                precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91       760
#            1       1.00      0.46      0.63       290
#
#     accuracy                           0.85      1050
#    macro avg       0.91      0.73      0.77      1050
# weighted avg       0.88      0.85      0.83      1050

# %%
df2 = pd.read_csv("test.csv")
df2.head()
# Out:
#    id       f_0       f_1       f_2       f_3       f_4       f_5       f_6  \
# 0   1 -3.388242  0.868285 -0.427619 -0.678964 -1.625735  0.262761  1.243040
# 1   2 -0.496920  0.952381  0.989040  0.451422  0.513516 -0.099658 -1.124326
# 2   3  1.128369 -0.537951  2.544358  1.165254 -1.904994  0.776961 -0.495768
# 3   4  0.051253  1.746814  0.681177  1.844524 -0.327977  1.226839 -0.085519
# 4   5  1.423209 -0.983594 -1.694170  1.197507  1.044211  0.518777 -0.298612
#
#         f_7       f_8  ...    f_1190    f_1191    f_1192    f_1193    f_1194  \
# 0  1.537751 -0.352028  ... -0.776403 -0.662884 -0.257091 -1.168413  0.223260
# 1  0.729430 -0.216224  ...  0.379635 -1.760084  1.125450 -0.328047 -0.880305
# 2  0.060111 -1.418468  ...  1.165254 -1.373589 -0.483701 -0.964782 -0.869555
# 3  0.379008 -1.003667  ... -0.442288 -2.794472 -0.763468 -0.789832 -0.113209
# 4 -0.365174  0.738447  ... -2.624450 -3.200223  0.711422 -0.190394  0.337224
#
# ...

# %%
X_test = df2.drop("id",axis=1)
X_test.shape
# Out:
# (2250, 1200)

# %% [markdown]
# /*Y_ans stores values of the labels of the test dataset provided by the competition*/

# %%
Y_ans = model.predict(X_test)

# %%
Y_ans.shape
# Out:
# (2250,)

# %%
Y_ans[2249]
# Out:
# 1

# %%
rows = np.empty((2250,2))
rows.shape
# Out:
# (2250, 2)

# %%
rows.dtype
# Out:
# dtype('float64')

# %%
new_rows = rows.astype('i')
new_rows.dtype
# Out:
# dtype('int32')

# %%
new_rows[1][0],new_rows[1][1]
# Out:
# (0, 0)

# %%
for i in range(2250):
    new_rows[i][0]=i+1
    new_rows[i][1]=Y_ans[i]

# %%
new_rows[3][0],new_rows[3][1],new_rows[2249][1]
# Out:
# (4, 0, 1)

# %%
# writing to CSV


import csv
	
# field names
fields = ['id', 'labels']
	
rows = new_rows
	
# name of csv file
filename = "solution.csv"
	
# writing to csv file 
with open(filename, 'w', newline = '') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
    # writing the fields 
    csvwriter.writerow(fields) 
        
    # writing the data rows 
    csvwriter.writerows(rows)

# %% [markdown]
# /*Solution.csv file is used for submission on bitgrit*/

# %%
# Y_ans[1300], Y_ans[1299]
# Out:
# (1, 0)

# %%
df4 = pd.read_csv("solution.csv")
df4.head()
# Out:
#    id  labels
# 0   1       0
# 1   2       0
# 2   3       0
# 3   4       0
# 4   5       0
